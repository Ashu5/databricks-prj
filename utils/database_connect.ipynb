# %% [markdown]
# &copy; 2025 Ashutoh Dwivedi

# %%
print("database connect setting....")
# %sql

# %%
# %sql
SELECT "Hello World"

# %%
# %fs ls /databricks-datasets/airlines

# %%
# %sh
tail /databricks-datasets/airlines/part-00000

# %%
# %lsmagic
